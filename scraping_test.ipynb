# %%
from gratka_scraper import GratkaScraper
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### Utworzenie instancji scrapera

# %%
scrapper = GratkaScraper()

# %% [markdown]
# ### Scrapowanie opisów

# %%
df = scrapper.description_scrapper(pages_from=1, pages_to=2)
# Out:
# Zawartość strony 1 została pobrana
# Zawartość strony 2 została pobrana

# %%
df.head()
# Out:
#   Label                                               Opis
# 0   NaN  Warsaw Estates ma do zaoferowania Państwu dwup...
# 1   NaN  Piękne, słoneczne 3-pokojowe mieszkanie z miej...
# 2   NaN  Do wynajęcia ciche, dwupokojowe mieszkanie na ...
# 3   NaN  Wynajmę 1-2  studentkom lub studentom z pierws...
# 4   NaN  Wynajmę bezpośrednio (proszę agencje o niekont...

# %% [markdown]
# ### Scrapowanie obrazów

# %%
scrapper.image_scrapper(pages_from=1, pages_to=1, save_path=r'C:\Users\wilko\Desktop\Studia\Projekty swoje\Python\Machine learning\NLP-text-classification\data\scraper_test')
# Out:
# Zawartość strony 1 została pobrana
# Postęp pobierania obrazów: 100%|██████████| 589/589 [02:17<00:00,  4.29it/s]

# %%
test_image = cv2.imread(r'C:\Users\wilko\Desktop\Studia\Projekty swoje\Python\Machine learning\NLP-text-classification\data\scraper_test\1\1_image_0.jpg')
test_image = cv2.cvtColor(test_image, cv2.COLOR_RGB2BGR)

# %%
plt.imshow(test_image)
