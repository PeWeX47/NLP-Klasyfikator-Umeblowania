# %%
from gratka_scraper import GratkaScraper
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### Utworzenie instancji scrapera

# %%
scrapper = GratkaScraper()

# %% [markdown]
# ### Scrapowanie opisów

# %%
df = scrapper.description_scrapper(pages_from=1, pages_to=2)

# %%
df.head()
# Out:
#   Label                                               Opis
# 0   NaN  Lokal 125 m/2 w Gdańsk Oliwa u zbiegu ul Al. G...
# 1   NaN  Mieszkanie w pelni wyposazone - dostępne do wp...
# 2   NaN  Przytulne, świeżo wyremontowane mieszkanie -  ...
# 3   NaN  Przytulne, świeżo wyremontowane mieszkanie - 3...
# 4   NaN  DOSTĘPNE OD 1 września 2023r. Bezpośredni wyna...

# %% [markdown]
# ### Scrapowanie obrazów

# %%
scrapper.image_scrapper(pages_from=2, pages_to=3, save_path=r'data\images')
# Out:
# Zawartość strony 2 została pobrana
# Postęp pobierania obrazów: 100%|██████████| 32/32 [01:38<00:00,  3.09s/it]
# Zawartość strony 3 została pobrana
# Postęp pobierania obrazów: 100%|██████████| 32/32 [01:46<00:00,  3.32s/it]

# %%
test_image = cv2.imread(r'data\images\strona_3\0\image_0.jpg')
test_image = cv2.cvtColor(test_image, cv2.COLOR_RGB2BGR)

# %%
plt.imshow(test_image)
